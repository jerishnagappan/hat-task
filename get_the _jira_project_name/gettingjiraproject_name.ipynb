# %%
import requests
from requests.auth import HTTPBasicAuth
import json


JIRA_DOMAIN = 'hashagile-team.atlassian.net'
API_TOKEN = 'ATATT3xFfGF0AZlHcAKrpR_O7TbNg_WdSYz4FvyHKteQ8t9ldjkpz8rQhpq3x6DDP1SeBveFZjmI6WZH8CVr3apomkcyAeVvqSCwQzGpJsR6Rllpr9Fduw1BZ5pY6keY94AjP7ZEoWfReDhfrdJBVNQnRkOgDMRDUcgGrBzsIi5qLFslG9_OMHw=2CC6C0E5'
EMAIL = 'jerish.nagappan@hashagile.com'


BASE_URL = f'https://{JIRA_DOMAIN}/rest/api/3'
PROJECTS_URL = f'{BASE_URL}/project'
FIELDS_URL = f'{BASE_URL}/field'

def get_projects():
    """Fetch all projects from Jira."""
    response = requests.get(
        PROJECTS_URL,
        auth=HTTPBasicAuth(EMAIL, API_TOKEN),
        headers={'Accept': 'application/json'}
    )
    response.raise_for_status()
    return response.json()

def get_fields():
    """Fetch all fields from Jira."""
    response = requests.get(
        FIELDS_URL,
        auth=HTTPBasicAuth(EMAIL, API_TOKEN),
        headers={'Accept': 'application/json'}
    )
    response.raise_for_status()
    return response.json()

def main():
    try:
        projects = get_projects()
        fields = get_fields()
        
    
        print(f"{'Project Name':<30} {'Jira Field Label':<30} {'Jira Field ID'}")
        print("="*80)
        
        for project in projects:
            project_name = project['name']
            for field in fields:
                field_label = field['name']
                field_id = field['id']
                print(f"{project_name:<30} {field_label:<30} {field_id}")

    except requests.RequestException as e:
        print(f"Error fetching data from Jira: {e}")

if __name__ == '__main__':
    main()
# Out:
# Project Name                   Jira Field Label               Jira Field ID
# ================================================================================
# databaseinsert                 Status Category Changed        statuscategorychangedate
# databaseinsert                 Parent                         parent
# databaseinsert                 Issue Type                     issuetype
# databaseinsert                 Time Spent                     timespent
# databaseinsert                 Story Points                   customfield_10030
# databaseinsert                 Project                        project
# databaseinsert                 Vulnerability                  customfield_10031
# databaseinsert                 Sentiment                      customfield_10032
# databaseinsert                 Fix versions                   fixVersions
# databaseinsert                 Design                         customfield_10033
# databaseinsert                 Σ Time Spent                   aggregatetimespent
# databaseinsert                 Status Category                statusCategory
# databaseinsert                 Resolution                     resolution
# databaseinsert                 Open forms                     customfield_10027
# databaseinsert                 Submitted forms                customfield_10028
# databaseinsert                 Total forms                    customfield_10029
# databaseinsert                 Resolved                       resolutiondate
# databaseinsert                 Work Ratio                     workratio
# databaseinsert                 Last Viewed                    lastViewed
# databaseinsert                 Watchers                       watches
# databaseinsert                 Restrict to                    issuerestriction
# databaseinsert                 Images                         thumbnail
# databaseinsert                 Created                        created
# databaseinsert                 Sprint                         customfield_10020
# databaseinsert                 Flagged                        customfield_10021
# databaseinsert                 Target start                   customfield_10022
# databaseinsert                 Priority                       priority
# databaseinsert                 Target end                     customfield_10023
# databaseinsert                 [CHART] Date of First Response customfield_10024
# databaseinsert                 [CHART] Time in Status         customfield_10025
# databaseinsert                 Labels                         labels
# databaseinsert                 Locked forms                   customfield_10026
# databaseinsert                 Story point estimate           customfield_10016
# databaseinsert                 Issue color                    customfield_10017
# databaseinsert                 Parent Link                    customfield_10018
# databaseinsert                 Rank                           customfield_10019
# databaseinsert                 Remaining Estimate             timeestimate
# databaseinsert                 Σ Original Estimate            aggregatetimeoriginalestimate
# databaseinsert                 Affects versions               versions
# databaseinsert                 Linked Issues                  issuelinks
# databaseinsert                 Assignee                       assignee
# databaseinsert                 Updated                        updated
# databaseinsert                 Status                         status
# databaseinsert                 Components                     components
# databaseinsert                 Key                            issuekey
# databaseinsert                 Original estimate              timeoriginalestimate
# databaseinsert                 Description                    description
# databaseinsert                 Request Type                   customfield_10010
# databaseinsert                 Epic Name                      customfield_10011
# databaseinsert                 Epic Status                    customfield_10012
# databaseinsert                 Epic Color                     customfield_10013
# databaseinsert                 Epic Link                      customfield_10014
# databaseinsert                 Time tracking                  timetracking
# databaseinsert                 Start date                     customfield_10015
# databaseinsert                 Change type                    customfield_10005
# databaseinsert                 Change risk                    customfield_10006
# databaseinsert                 Security Level                 security
# databaseinsert                 Change reason                  customfield_10007
# databaseinsert                 Actual start                   customfield_10008
# databaseinsert                 Attachment                     attachment
# databaseinsert                 Σ Remaining Estimate           aggregatetimeestimate
# databaseinsert                 Actual end                     customfield_10009
# databaseinsert                 Summary                        summary
# databaseinsert                 Creator                        creator
# databaseinsert                 Sub-tasks                      subtasks
# databaseinsert                 Reporter                       reporter
# databaseinsert                 Σ Progress                     aggregateprogress
# databaseinsert                 Development                    customfield_10000
# databaseinsert                 Team                           customfield_10001
# databaseinsert                 Organizations                  customfield_10002
# databaseinsert                 Approvers                      customfield_10003
# databaseinsert                 Impact                         customfield_10004
# databaseinsert                 Environment                    environment
# databaseinsert                 Due date                       duedate
# databaseinsert                 Progress                       progress
# databaseinsert                 Votes                          votes
# databaseinsert                 Comment                        comment
# databaseinsert                 Log Work                       worklog
# snowflake                      Status Category Changed        statuscategorychangedate
# snowflake                      Parent                         parent
# snowflake                      Issue Type                     issuetype
# snowflake                      Time Spent                     timespent
# snowflake                      Story Points                   customfield_10030
# snowflake                      Project                        project
# snowflake                      Vulnerability                  customfield_10031
# snowflake                      Sentiment                      customfield_10032
# snowflake                      Fix versions                   fixVersions
# snowflake                      Design                         customfield_10033
# snowflake                      Σ Time Spent                   aggregatetimespent
# snowflake                      Status Category                statusCategory
# snowflake                      Resolution                     resolution
# snowflake                      Open forms                     customfield_10027
# snowflake                      Submitted forms                customfield_10028
# snowflake                      Total forms                    customfield_10029
# snowflake                      Resolved                       resolutiondate
# snowflake                      Work Ratio                     workratio
# snowflake                      Last Viewed                    lastViewed
# snowflake                      Watchers                       watches
# snowflake                      Restrict to                    issuerestriction
# snowflake                      Images                         thumbnail
# snowflake                      Created                        created
# snowflake                      Sprint                         customfield_10020
# snowflake                      Flagged                        customfield_10021
# snowflake                      Target start                   customfield_10022
# snowflake                      Priority                       priority
# snowflake                      Target end                     customfield_10023
# snowflake                      [CHART] Date of First Response customfield_10024
# snowflake                      [CHART] Time in Status         customfield_10025
# snowflake                      Labels                         labels
# snowflake                      Locked forms                   customfield_10026
# snowflake                      Story point estimate           customfield_10016
# snowflake                      Issue color                    customfield_10017
# snowflake                      Parent Link                    customfield_10018
# snowflake                      Rank                           customfield_10019
# snowflake                      Remaining Estimate             timeestimate
# snowflake                      Σ Original Estimate            aggregatetimeoriginalestimate
# snowflake                      Affects versions               versions
# snowflake                      Linked Issues                  issuelinks
# snowflake                      Assignee                       assignee
# snowflake                      Updated                        updated
# snowflake                      Status                         status
# snowflake                      Components                     components
# snowflake                      Key                            issuekey
# snowflake                      Original estimate              timeoriginalestimate
# snowflake                      Description                    description
# snowflake                      Request Type                   customfield_10010
# snowflake                      Epic Name                      customfield_10011
# snowflake                      Epic Status                    customfield_10012
# snowflake                      Epic Color                     customfield_10013
# snowflake                      Epic Link                      customfield_10014
# snowflake                      Time tracking                  timetracking
# snowflake                      Start date                     customfield_10015
# snowflake                      Change type                    customfield_10005
# snowflake                      Change risk                    customfield_10006
# snowflake                      Security Level                 security
# snowflake                      Change reason                  customfield_10007
# snowflake                      Actual start                   customfield_10008
# snowflake                      Attachment                     attachment
# snowflake                      Σ Remaining Estimate           aggregatetimeestimate
# snowflake                      Actual end                     customfield_10009
# snowflake                      Summary                        summary
# snowflake                      Creator                        creator
# snowflake                      Sub-tasks                      subtasks
# snowflake                      Reporter                       reporter
# snowflake                      Σ Progress                     aggregateprogress
# snowflake                      Development                    customfield_10000
# snowflake                      Team                           customfield_10001
# snowflake                      Organizations                  customfield_10002
# snowflake                      Approvers                      customfield_10003
# snowflake                      Impact                         customfield_10004
# snowflake                      Environment                    environment
# snowflake                      Due date                       duedate
# snowflake                      Progress                       progress
# snowflake                      Votes                          votes
# snowflake                      Comment                        comment
# snowflake                      Log Work                       worklog
